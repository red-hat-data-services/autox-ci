# %%
# !uv pip install pandas
# Out:
# Resolved 4 packages in 464ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)-------------------     0 B/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 16.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 32.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 48.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 64.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 80.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 96.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 112.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 128.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 144.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 160.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 176.00 KiB/9.43 MiB
# ⠙ Preparing packages... (0/1)------------------- 192.00 KiB/9.43 MiB
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("e2e-tests/data/automl/classification_multi/car_rental_training_data.csv", delimiter=";")

_ba = df["Business_Area"]
# Remove rows where Business_Area is NaN or empty / whitespace-only
df = df[_ba.notna() & _ba.astype(str).str.strip().ne("")]

_ba = df["Action"]
# Remove rows where Business_Area is NaN or empty / whitespace-only
df = df[_ba.notna() & _ba.astype(str).str.strip().ne("")]
print(df.shape)
# Out:
# (486, 11)

# %%
# Out:
# (486, 11)

# %%
df.to_csv("e2e-tests/data/automl/classification_multi/car_rental_training_data_quotes.csv", index=False, sep=",")
